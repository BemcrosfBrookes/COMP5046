# %% [markdown]
# <a href="https://colab.research.google.com/github/BemcrosfBrookes/COMP5046/blob/main/state.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#state.py

from datetime import datetime


MEDICATION_REMINDERS = {
    # "user_email": [
    #  something like {"medicine_id": "med1", "name": "Paracetamol", "custom_time": "09:30"},
    # ]
}

SESSION = {
    "logged_in": False,
    "email": None,
    "current_screen": "login",
    "notifications_on": True,
    "default_notification_time": "08:00"
}

PROFILE_STORE = {
    # "user_email": {"name": "...", "surname": "...", "email": "..."}
}


medicines = []          # will be loaded from .json file
MEDICINE_FILE = "medicines_data.json"


def get_logged_in_email():
    if not SESSION.get("logged_in"):
        return None
    return SESSION.get("email")


def notifications_allowed():
    return SESSION.get("notifications_on", True)
